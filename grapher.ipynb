# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

df = pd.read_csv(r'C:\Users\Lucas\OneDrive\Área de Trabalho\Meus Documentos\Einstein\7º Semestre\PBL\software\coletas\ryan2_coleta.csv')

# %%
df

# %%
os.chdir('imagens')
for i in range(len(df.columns)):
    plt.figure(figsize=(50,8))
    sns.lineplot(data=df, x= df['tempo_vetorizado'], y=df[df.columns[i]])
    plt.savefig(f'{df.columns[i]}')
